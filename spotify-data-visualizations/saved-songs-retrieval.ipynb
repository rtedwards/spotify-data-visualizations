# %%
#"user-read-private user-read-email user-read-playback-state user-read-currently-playing user-library-read"
#export SPOTIPY_CLIENT_ID='c27d762046d144e48d9d7d929e9c2206'
#export SPOTIPY_CLIENT_SECRET='fd9583d5356249e1a32e262640b989dc'
#export SPOTIPY_REDIRECT_URI='http://localhost/8888'

# 'user-library-read playlist-read-private'
'''
user-read-private \
user-read-email \
user-read-recently-played \
user-read-playback-state \
user-read-currently-playing \
user-library-read \
playlist-modify-public \
playlist-read-private \
user-follow-read \
user-top-read streaming
'''
    
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.util as util


client_id ="c27d762046d144e48d9d7d929e9c2206" 
client_secret = "fd9583d5356249e1a32e262640b989dc"
redirect_uri = "https://localhost/8888"
username = ""
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret) 
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
scope = 'user-library-read \
        playlist-read-private' 
token = util.prompt_for_user_token(username, scope, client_id, client_secret, redirect_uri)

    
if token:
    print("Listing user's currently saved tracks:\n")
    sp = spotipy.Spotify(auth=token)
    results = sp.current_user_saved_tracks(50)
    for item in results['items']:
        track = item['track']
        print(track['name'] + ' - ' + track['artists'][0]['name'])
else:
    print("Can't get token for", username)

    
sourcePlaylist = sp.user_playlist("1266075212", "5GRTnW4nCpeckVmQRqV2tj")
tracks = sourcePlaylist["tracks"]
songs = tracks["items"] 
while tracks['next']:
    tracks = sp.next(tracks)
    for item in tracks["items"]:
        songs.append(item)

ids = [] 
print("")
print("Number of songs:", len(songs))
#print(songs[0]['track']['id'])

i = 0
for i in range(len(songs)):
    sp.user_playlist_add_tracks("1266075212", "0pI3PXxlFHPa50HSDTMelb", [songs[i]["track"]["id"]])
# Out:
# Listing user's currently saved tracks:
#
# MAFIA - Devault
# 10 Years Einmusika mixed by Budakid - Continuous DJ Mix - Budakid
# Our Love - Caribou
# Fall In Love - Until The Ribbon Breaks Reimagination - Phantogram
# Bengal - Hidden Empire
# Panther - Hidden Empire
# Again Again - Hidden Empire
# Hummus - Hidden Empire
# Sierra - Hidden Empire
# Echo - Lycoriscoris
# Kite - Lycoriscoris
# Cyclus - Ryan Davis
# Will I Ever Find Love - Spencer Brown
# Ibrik - Bonobo
# Order from Chaos - Max Cooper
# One - Weval
# What Is There - Chihei Hatakeyama
# Dew - Polynation
# A Place - Nils Frahm
# Same Old - Theo Kottis
# Drums Saved Me - DJ Stingray Original Mix - DJ Stingray
# False Awakenings - Original Mix - DAVI
# Open Arms - RKCB
# Again (feat. Totally Enormous Extinct Dinosaurs) - SG Lewis
# Where Do You Go - Charlotte Day Wilson
# Entity - Tora
# Over U - Stwo
# Journey Into The Unknown - Amber Mark
# My Place - Tora
# Love Me Right - Amber Mark
# Too Much - Tora
# Dreamland - ESTA.
# Little Lies - ODIE
# Maria - Shagabond
# At Dawn - Joe Hertz
# Lose My Cool - Amber Mark
# Pulsar - Lone
# Odyssey - Dark Sky
# Nordschleife - Jacques Greene
# Anaphora - Ochre
# Feel Infinite - Jacques Greene
# Poly - Daphni
# Fragments of Self - Max Cooper
# Field Tower - Dark Sky
# Laurels - Dark Sky
# Trust - Christian Löffler Revision - Max Cooper
# Two Suns - CloZee Remix - Tor
# Eclipse - IHF
# Canyon Walls - Koresma
# Fork in the Road - Koresma
#
# Number of songs: 26

# %%
print(results)
# Out:
# {'href': 'https://api.spotify.com/v1/me/tracks?offset=0&limit=20', 'items': [{'added_at': '2019-05-27T20:08:22Z', 'track': {'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1VBAKMui4zm5MnBWNn3NbL'}, 'href': 'https://api.spotify.com/v1/artists/1VBAKMui4zm5MnBWNn3NbL', 'id': '1VBAKMui4zm5MnBWNn3NbL', 'name': 'Devault', 'type': 'artist', 'uri': 'spotify:artist:1VBAKMui4zm5MnBWNn3NbL'}], 'available_markets': ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'SA', 'SE', 'SG', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'US', 'UY', 'VN', 'ZA'], 'external_urls': {'spotify': 'https://open.spotify.com/album/1MIgd23QGGcqzysbQJquUu'}, 'href': 'https://api.spotify.com/v1/albums/1MIgd23QGGcqzysbQJquUu', 'id': '1MIgd23QGGcqzysbQJquUu', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/67bf4b76eefd969da816312e122f45f345d9e155', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/152c8d1880d252e1c434103c467304c399be7c39', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/92d3d56695fbbfb3b102ccee96d4e6244739878c', 'width': 64}], 'name': 'JADE', 'release_date': '2019-04-26', 'release_date_precision': 'day', 'total_tracks': 4, 'type': 'album', 'uri': 'spotify:album:1MIgd23QGGcqzysbQJquUu'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1VBAKMui4zm5MnBWNn3NbL'}, 'href': 'https://api.spotify.com/v1/artists/1VBAKMui4zm5MnBWNn3NbL', 'id': '1VBAKMui4zm5MnBWNn3NbL', 'name': 'Devault', 'type': 'artist', 'uri': 'spotify:artist:1VBAKMui4zm5MnBWNn3NbL'}], 'available_markets': ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'SA', 'SE', 'SG', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'US', 'UY', 'VN', 'ZA'], 'disc_number': 1, 'duration_ms': 226668, 'explicit': False, 'external_ids': {'isrc': 'USUM71906469'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/7D39FDg7UK4k66zpr5fBoR'}, 'href': 'https://api.spotify.com/v1/tracks/7D39FDg7UK4k66zpr5fBoR', 'id': '7D39FDg7UK4k66zpr5fBoR', 'is_local': False, 'name': 'MAFIA', 'popularity': 34, 'preview_url': 'https://p.scdn.co/mp3-preview/f581e3a68b8d8c6c257befa93fe0c74f67454511?cid=c27d762046d144e48d9d7d929e9c2206', 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:7D39FDg7UK4k66zpr5fBoR'}}, {'added_at': '2019-05-27T01:55:57Z', 'track': {'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2MNTXvxPuFuHRYSMN7EEFL'}, 'href': 'https://api.spotify.com/v1/artists/2MNTXvxPuFuHRYSMN7EEFL', 'id': '2MNTXvxPuFuHRYSMN7EEFL', 'name': 'Budakid', 'type': 'artist', 'uri': 'spotify:artist:2MNTXvxPuFuHRYSMN7EEFL'}], 'available_markets': ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'SA', 'SE', 'SG', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'US', 'UY', 'VN', 'ZA'], 'external_urls': {'spotify': 'https://open.spotify.com/album/4M7AkfilqDL3B8mZtwjdCI'}, 'href': 'https://api.spotify.com/v1/albums/4M7AkfilqDL3B8mZtwjdCI', 'id': '4M7Akfilq ...
